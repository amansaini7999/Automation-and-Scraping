# %%
import face_recognition
import cv2

# %%
url = "http://192.168.43.1:8080/video"

ch = int(input("1. Registration\n2. Unlock\n\nEnter your Choice : "))

if(ch==1):
    name = input("Enter name : ")
    cap = cv2.VideoCapture(url)
    
    while(True):
        ret, frame = cap.read()
        face_locations = face_recognition.face_locations(frame)
        
        if(len(face_locations) > 0):
            print("Found")
            for i in range(len(face_locations)):
                x1 = face_locations[i][0]
                y1 = face_locations[i][1]
                x2 = face_locations[i][2]
                y2 = face_locations[i][3]
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 10)
                
        else:
            print("No Faces")
        
        cv2.imshow('frame',frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
            
    cap.release()
    cv2.destroyAllWindows()
    
else:
    cap = cv2.VideoCapture(url)
    
    while(True):
        ret, frame = cap.read()
        
        cv2.imshow('frame',frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
            
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1. Registration
# 2. Unlock
#
# Enter your Choice : 1
# Enter name : aman
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# Found
# Found
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# Found
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# Found
# No Faces
# No Faces
# Found
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# Found
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# Found
# Found
# No Faces
# Found
# Found
# Found
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
# No Faces
